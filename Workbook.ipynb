# %%
# Import glob for file manipulation
import glob

import os

# Import functions from Funky.ipynb
from Funky import volumen_inicial, concentración_final, volumen_final

# volumen_inicial(archivo, vol_final=, concentración_final=)  Calcula volumen a tomar a partir de una concentración inicial, volúmen final y concentración final
# concentración_final(archivo, vol_inicial=, vol_final=)      Calcula concentración final a partir de volumen a tomar y volumen final establecido
# volumen_final(archivo, vol_inicial=, concentración_final=)  Calcula volumen final para una concentración inicial conocida, volumen a tomar y concentración final establecida

# %%
# Muestra lista de archivos disponibles 

path = ""

files = glob.glob(path, recursive=True) 
file_names = [os.path.basename(f) for f in files]
print(file_names)
# Out:
# ['RNA_Vanessa.csv', 'RNA_DILUCIONES.csv']

# %%
# Selecciona el nombre del archivo a trabajar
archivo = ""
